# %%
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib notebook
import scipy as sp

# %%
# wl,spectrum,Gdd = sp.loadtxt('test_file.txt',delimiter=', ', skiprows=1, unpack= True)
wl1,Gdd1 = sp.loadtxt('speed_difference_data_1.txt',delimiter=', ', skiprows=1, unpack= True)
# wl = data[:,0]
# sectrum = data[:,1]
# Gdd = data[:,2]
# N=len(timeS)
# R=1.0e6
# D_time = 1/R
# T = N/R
# wl_laser = 633e-9  #in m
# N_FFT = 2**16  
# c = 299792458      #speed of light in m/s

# signal_HeNe=(signal_HeNe-signal_HeNe.mean())/(sp.absolute(signal_HeNe-signal_HeNe.mean())).max() #normalize and shift around zero
# signal_SC=(signal_SC-signal_SC.mean())/(sp.absolute(signal_SC-signal_SC.mean())).max()
# plt.figure()
# plt.plot(wl*1e9,20*sp.log10(spectrum))
# plt.xlabel('Wavelength(nm)')
# plt.ylabel('Power (dB)')
# plt.xlim(1000,1150)
# plt.ylim(-45,-15)
# plt.plot(wl*1e9,Gdd)

# plt.savefig('IR', format = None)

# %%
kern_win_size = 21  # it was 2001 
x_kern = sp.linspace(-6,6,kern_win_size)
kern = sp.exp(-x_kern**2/4)
kern /= kern.sum() # equivalent to kern = kern/kern.sum()

# GDD_avg = sp.convolve(Gdd,kern,'same')
GDD_avg1 = sp.convolve(Gdd1,kern,'same')
plt.figure()
# plt.plot(wl*1e9,GDD_avg)
plt.plot(wl1,GDD_avg1)
plt.xlabel('Wavelength(nm)')
plt.ylabel('Gdd (fs^2)')
plt.xlim(1026,1120)
plt.ylim(-500,500)

plt.savefig('GDD_250fs', format = None)
# Out:
# <img src="data:image/png;base64,...">
