# %%
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib notebook
import scipy as sp

# %%
wl,spectrum,Gdd*1e30 = sp.loadtxt('1stGDD_Measurement.txt',delimiter=', ', skiprows=1, unpack= True)

# plt.plot(wl*1e9,20*sp.log10(spectrum))
# plt.xlabel('Wavelength(nm)')
# plt.ylabel('Power (dB)')
# plt.xlim(1000,1150)
# plt.ylim(-45,-15)
# plt.plot(wl*1e9,Gdd)

# plt.savefig('IR', format = None)
# Out:
#   File "<ipython-input-14-6b5646374a64>", line 1
#     wl,spectrum,Gdd*1e30 = sp.loadtxt('1stGDD_Measurement.txt',delimiter=', ', skiprows=1, unpack= True)
#                                                                                                         ^
# SyntaxError: can't assign to operator

# %%
kern_win_size = 21  # it was 2001 
x_kern = sp.linspace(-6,6,kern_win_size)
kern = sp.exp(-x_kern**2/4)
kern /= kern.sum() # equivalent to kern = kern/kern.sum()

GDD_avg = sp.convolve(Gdd,kern,'same')

plt.plot(wl*1e9,GDD_avg)
plt.xlabel('Wavelength(nm)')
plt.ylabel('Gdd (fs^2)')
plt.xlim(1025,1120)
plt.ylim(-500,500)

# plt.savefig('IR', format = None)
# Out:
# <img src="data:image/png;base64,...">
# (-500, 500)
